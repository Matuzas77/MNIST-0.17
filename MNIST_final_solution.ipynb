# %%
"""
MNIST Ensemble Classifier - Professional Implementation

This notebook demonstrates the usage of the refactored, professional MNIST classifier.
For the full implementation, see mnist_classifier.py
"""

import tensorflow as tf
import numpy as np
from mnist_classifier import Config, EnsembleTrainer, DataPreprocessor

print(f"TensorFlow version: {tf.__version__}")
print(f"GPU available: {len(tf.config.list_physical_devices('GPU')) > 0}")

# %%
# Initialize configuration
config = Config()

# For demonstration purposes, we'll train fewer models to save time
# For best results (0.16% error), use config.NUM_MODELS = 20
config.NUM_MODELS = 5  # Reduced for faster demonstration

print("Configuration:")
print(f"  Number of models: {config.NUM_MODELS}")
print(f"  Batch size: {config.BATCH_SIZE}")
print(f"  Initial learning rate: {config.INITIAL_LEARNING_RATE}")
print(f"  Mixed precision: {config.USE_MIXED_PRECISION}")

# %%
# Load and preprocess data
print("Loading and preprocessing MNIST dataset...")
preprocessor = DataPreprocessor(config)
(x_train, y_train), (x_test, y_test) = preprocessor.load_and_preprocess_data()

print(f"\nData shapes:")
print(f"  Training: {x_train.shape}, {y_train.shape}")
print(f"  Test: {x_test.shape}, {y_test.shape}")
print(f"\nData range: [{x_train.min():.2f}, {x_train.max():.2f}]")

# %%
# Visualize the model architecture
from mnist_classifier import MNISTModel

model_builder = MNISTModel(config)
sample_model = model_builder.build_model()

print("Model Architecture Summary:")
print("="*70)
sample_model.summary()
print("="*70)
print(f"\nTotal parameters: {sample_model.count_params():,}")
print(f"Trainable parameters: {sum([tf.size(w).numpy() for w in sample_model.trainable_weights]):,}")

# %%
# Visualize sample training data with augmentation
import matplotlib.pyplot as plt

# Create data augmentation
datagen = preprocessor.create_data_augmentation()
datagen.fit(x_train)

# Generate augmented samples
fig, axes = plt.subplots(2, 5, figsize=(12, 5))
fig.suptitle('Sample MNIST Digits with Data Augmentation', fontsize=14, fontweight='bold')

for i, ax in enumerate(axes.flat):
    # Get a sample
    idx = np.random.randint(0, len(x_train))
    img = x_train[idx:idx+1]
    label = np.argmax(y_train[idx])
    
    # Apply augmentation
    aug_iter = datagen.flow(img, batch_size=1)
    aug_img = next(aug_iter)[0]
    
    # Display
    ax.imshow(aug_img.squeeze() + 0.5, cmap='gray')
    ax.set_title(f'Digit: {label}')
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
# Train the ensemble
print("Training ensemble of models...")
print("="*70)
print("This will train multiple models with different random seeds.")
print(f"Number of models: {config.NUM_MODELS}")
print("="*70)

trainer = EnsembleTrainer(config)
models = trainer.train_ensemble(x_train, y_train, x_test, y_test)

print(f"\n{'='*70}")
print(f"Successfully trained {len(models)} models!")
print(f"{'='*70}")

# %%
# Evaluate the ensemble
from sklearn.metrics import accuracy_score

print("Evaluating ensemble performance...")
print("="*70)

# Get individual model accuracies
individual_accuracies = []
for i, model in enumerate(models):
    predictions = model.predict(x_test, verbose=0)
    accuracy = accuracy_score(
        np.argmax(y_test, axis=1),
        np.argmax(predictions, axis=1)
    )
    individual_accuracies.append(accuracy)
    print(f"Model {i+1:2d} accuracy: {accuracy:.4f} (error: {(1-accuracy)*100:.2f}%)")

print(f"\n{'='*70}")
print(f"Average individual accuracy: {np.mean(individual_accuracies):.4f}")
print(f"Std deviation: {np.std(individual_accuracies):.4f}")
print(f"{'='*70}")

# %%
# Compute ensemble predictions by averaging
print("Computing ensemble predictions...")

# Get predictions from all models
all_predictions = np.array([model.predict(x_test, verbose=0) for model in models])

# Average predictions
ensemble_predictions = np.mean(all_predictions, axis=0)

print(f"Prediction array shape: {all_predictions.shape}")
print(f"Ensemble prediction shape: {ensemble_predictions.shape}")

# %%
# Calculate final ensemble accuracy
ensemble_accuracy = accuracy_score(
    np.argmax(y_test, axis=1),
    np.argmax(ensemble_predictions, axis=1)
)

print("\n" + "="*70)
print("FINAL RESULTS")
print("="*70)
print(f"Number of models in ensemble: {len(models)}")
print(f"Average individual model accuracy: {np.mean(individual_accuracies):.4f}")
print(f"Ensemble accuracy: {ensemble_accuracy:.4f}")
print(f"Ensemble error rate: {(1-ensemble_accuracy)*100:.2f}%")
print("="*70)

# Calculate improvement
improvement = (ensemble_accuracy - np.mean(individual_accuracies)) * 100
print(f"\nEnsemble improvement: +{improvement:.2f} percentage points")
print(f"Error reduction: {((1-np.mean(individual_accuracies))-(1-ensemble_accuracy))/(1-np.mean(individual_accuracies))*100:.1f}%")

# %%
# Visualize predictions on some test samples
fig, axes = plt.subplots(2, 5, figsize=(15, 6))
fig.suptitle('Ensemble Predictions on Test Samples', fontsize=14, fontweight='bold')

# Get some random test samples
indices = np.random.choice(len(x_test), 10, replace=False)

for idx, ax in zip(indices, axes.flat):
    img = x_test[idx]
    true_label = np.argmax(y_test[idx])
    pred_label = np.argmax(ensemble_predictions[idx])
    confidence = ensemble_predictions[idx, pred_label] * 100
    
    # Display image
    ax.imshow(img.squeeze() + 0.5, cmap='gray')
    
    # Color code: green if correct, red if wrong
    color = 'green' if pred_label == true_label else 'red'
    ax.set_title(
        f'True: {true_label}, Pred: {pred_label}\nConf: {confidence:.1f}%',
        color=color,
        fontweight='bold'
    )
    ax.axis('off')

plt.tight_layout()
plt.show()

# Summary
print("\n" + "="*70)
print("PROFESSIONAL CODE IMPROVEMENTS SUMMARY")
print("="*70)
print("✓ Modern TensorFlow APIs (no deprecated functions)")
print("✓ Type hints and comprehensive docstrings")
print("✓ Proper code organization with classes")
print("✓ Configuration management")
print("✓ Professional logging")
print("✓ Mixed precision training support")
print("✓ Better memory management")
print("✓ Fixed normalization bug")
print("✓ Optimized data pipeline")
print("="*70)
